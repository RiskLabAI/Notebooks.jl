# %%
using CSV, DataFrames
include("controller/data_structure_controller.jl");

# %%
data = CSV.File("../ahrom_edited.csv") |> DataFrame;
data.date = DateTime.(data.date, "yyyy/mm/dd H:M:S.s");

# %% [markdown]
# # Dollar Bars

# %%
@time dollarStandardBars = handleInput(
    "DollarStandardBars",
    Dict(
        Symbol("threshold") => 10_000_000_000.0
    ),
    data,
    batchSize=1_000_000,  
)

dollarStandardBars
# Out:
# batch 1 with size 729726
#   1.584372 seconds (5.25 M allocations: 195.657 MiB, 2.27% gc time, 90.23% compilation time)
# 15509×12 DataFrame
#    Row │ Date Time            Tick Number  Open     High     Low      Close    ⋯
#        │ DateTime             Int64        Float64  Float64  Float64  Float64  ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │ 2022-06-01T10:00:36          123  13170.0    NaN      NaN    12880.0  ⋯
#      2 │ 2022-06-01T10:19:22          187  12880.0  13380.0  12880.0  13380.0
#      3 │ 2022-06-01T10:31:18          213  13390.0  13390.0  13030.0  13170.0
#      4 │ 2022-06-01T11:01:24          250  13180.0  13180.0  13060.0  13080.0
#      5 │ 2022-06-01T11:37:18          308  13080.0  13170.0  13060.0  13090.0  ⋯
#      6 │ 2022-06-01T11:56:25          365  13090.0  13140.0  13030.0  13100.0
#      7 │ 2022-06-01T12:20:03          436  13080.0  13100.0  13000.0  13100.0
# ...

# %% [markdown]
# # Volume Bars

# %%
@time volumeStandardBars = handleInput(
    "VolumeStandardBars",
    Dict(
        Symbol("threshold") => 1_000_000.0
    ),
    data,
    batchSize=1_000_000,  
)

volumeStandardBars
# Out:
# batch 1 with size 729726
#   0.447829 seconds (3.23 M allocations: 95.593 MiB, 12.74% gc time, 54.83% compilation time)
# 10756×12 DataFrame
#    Row │ Date Time            Tick Number  Open     High     Low      Close    ⋯
#        │ DateTime             Int64        Float64  Float64  Float64  Float64  ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │ 2022-06-01T10:16:46          147  13170.0    NaN      NaN    13050.0  ⋯
#      2 │ 2022-06-01T10:29:04          202  13050.0  13390.0  12990.0  13100.0
#      3 │ 2022-06-01T11:01:24          249  13100.0  13180.0  13060.0  13080.0
#      4 │ 2022-06-01T11:40:30          319  13080.0  13170.0  13060.0  13070.0
#      5 │ 2022-06-01T12:16:38          419  13080.0  13140.0  13000.0  13020.0  ⋯
#      6 │ 2022-06-01T12:28:51          466  13020.0  13180.0  13010.0  13050.0
#      7 │ 2022-06-06T09:15:55          540  13050.0  13200.0  12800.0  12800.0
# ...

# %% [markdown]
# # Tick Bars

# %%
@time tickStandardBars = handleInput(
    "TickStandardBars",
    Dict(
        Symbol("threshold") => 100.0
    ),
    data,
    batchSize=1_000_000,  
)

tickStandardBars
# Out:
# batch 1 with size 729726
#   0.291320 seconds (2.96 M allocations: 85.839 MiB, 68.67% compilation time)
# 7297×12 DataFrame
#   Row │ Date Time            Tick Number  Open     High     Low      Close     ⋯
#       │ DateTime             Int64        Float64  Float64  Float64  Float64   ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ 2022-06-01T09:48:19          100  13170.0    NaN      NaN    12890.0   ⋯
#     2 │ 2022-06-01T10:27:42          200  12890.0  13390.0  12880.0  13100.0
#     3 │ 2022-06-01T11:36:38          300  13100.0  13180.0  13060.0  13120.0
#     4 │ 2022-06-01T12:13:22          400  13120.0  13140.0  13030.0  13040.0
#     5 │ 2022-06-06T09:09:27          500  13040.0  13200.0  12870.0  12880.0   ⋯
#     6 │ 2022-06-06T09:30:22          600  12880.0  12890.0  12730.0  12750.0
#     7 │ 2022-06-06T09:46:20          700  12740.0  12750.0  12380.0  12380.0
# ...
