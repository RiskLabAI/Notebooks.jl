# %%
using CSV, DataFrames
include("controller/data_structure_controller.jl");

# %%
data = CSV.File("../ahrom_edited.csv") |> DataFrame;
data.date = DateTime.(data.date, "yyyy/mm/dd H:M:S.s");

# %% [markdown]
# # Expected Imbalance Bars

# %%
include("controller/data_structure_controller.jl");

@time expectedDollarImbalanceBars = handleInput(
    "ExpectedDollarImbalanceBars",
    Dict(
        Symbol("windowSizeForExpectedNTicksEstimation") => 5,
        Symbol("expectedImbalanceWindow") => 10000,
        Symbol("initialEstimateOfExpectedNTicksInBar") => 2000.0,
    ),
    data,
    batchSize=1_000_000,
)

expectedDollarImbalanceBars
# Out:
# batch 1 with size 729726
#   0.788479 seconds (3.19 M allocations: 118.370 MiB, 9.52% gc time, 82.04% compilation time)
# 32×12 DataFrame
#  Row │ Date Time            Tick Number  Open     High     Low      Close    C ⋯
#      │ DateTime             Int64        Float64  Float64  Float64  Float64  F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2022-06-11T10:12:57         2441  13170.0    NaN      NaN    12210.0    ⋯
#    2 │ 2022-06-12T09:18:21         3245  12210.0  12400.0  12020.0  12100.0
#    3 │ 2022-06-12T11:41:46         4257  12100.0  12770.0  12100.0  12650.0
#    4 │ 2022-06-13T09:51:49         5635  12650.0  13450.0  12640.0  13350.0
#    5 │ 2022-06-14T10:49:06         7383  13350.0  13450.0  13190.0  13270.0    ⋯
#    6 │ 2022-06-19T11:12:04         9401  13280.0  13340.0  12620.0  12780.0
#    7 │ 2022-06-20T11:33:17        10159  12780.0  13050.0  12710.0  12860.0
# ...

# %%
@time expectedVolumeImbalanceBars = handleInput(
    "ExpectedVolumeImbalanceBars",
    Dict(
        Symbol("windowSizeForExpectedNTicksEstimation") => 5,
        Symbol("expectedImbalanceWindow") => 10000,
        Symbol("initialEstimateOfExpectedNTicksInBar") => 2000.0,
    ),  
    df,
    batchSize=1_000_000,  
)

expectedVolumeImbalanceBars
# Out:
# batch 1 with size 729726
# 279.783906 seconds (33.99 M allocations: 56.844 GiB, 2.52% gc time, 0.09% compilation time)
# 373451×12 DataFrame
#     Row │ Date Time            Tick Number  Open     High     Low      Close   ⋯
#         │ DateTime             Int64        Float64  Float64  Float64  Float64 ⋯
# ────────┼───────────────────────────────────────────────────────────────────────
#       1 │ 2022-06-11T10:12:56         2439  13170.0    NaN      NaN    12210.0 ⋯
#       2 │ 2022-06-12T09:18:20         3235  12210.0  12400.0  12020.0  12100.0
#       3 │ 2022-06-12T11:30:20         4210  12100.0  12770.0  12100.0  12600.0
#       4 │ 2022-06-13T09:51:48         5625  12600.0  13450.0  12600.0  13350.0
#       5 │ 2022-06-14T10:43:20         7343  13350.0  13450.0  13190.0  13330.0 ⋯
#       6 │ 2022-06-19T09:43:18         9252  13320.0  13340.0  12620.0  12820.0
#       7 │ 2022-06-20T10:48:42        10115  12880.0  13050.0  12710.0  12890.0
# ...

# %%
@time expectedTickImbalanceBars = handleInput(
    "ExpectedTickImbalanceBars",
    Dict(
        Symbol("windowSizeForExpectedNTicksEstimation") => 5,
        Symbol("expectedImbalanceWindow") => 10000,
        Symbol("initialEstimateOfExpectedNTicksInBar") => 2000.0,
    ),
    df,
    batchSize=1_000_000,  
)

expectedTickImbalanceBars
# Out:
# batch 1 with size 729726
#   0.462052 seconds (2.62 M allocations: 89.279 MiB, 18.74% gc time, 63.45% compilation time)
# 38×12 DataFrame
#  Row │ Date Time            Tick Number  Open     High     Low      Close    C ⋯
#      │ DateTime             Int64        Float64  Float64  Float64  Float64  F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2022-06-08T11:23:43         2044  13170.0    NaN      NaN    12470.0    ⋯
#    2 │ 2022-06-12T10:17:10         3624  12470.0  12630.0  12020.0  12350.0
#    3 │ 2022-06-13T09:59:35         5847  12350.0  13450.0  12350.0  13350.0
#    4 │ 2022-06-15T09:40:51         8100  13350.0  13440.0  12910.0  12940.0
#    5 │ 2022-06-20T11:33:17        10160  12940.0  13100.0  12620.0  12860.0    ⋯
#    6 │ 2022-06-25T11:33:57        11685  12860.0  12960.0  12250.0  12250.0
#    7 │ 2022-07-06T12:28:53        17135  12250.0  12330.0  11620.0  11620.0
# ...

# %% [markdown]
# # Const Imbalance Bars

# %%
@time fixedDollarImbalanceBars = handleInput(
    "FixedDollarImbalanceBars",
    Dict(
        Symbol("expectedImbalanceWindow") => 10000,
        Symbol("initialEstimateOfExpectedNTicksInBar") => 20000.0,
    ),
    df,
    batchSize=1_000_000,  
)

fixedDollarImbalanceBars
# Out:
# batch 1 with size 729726
#   0.350133 seconds (3.15 M allocations: 110.496 MiB, 86.15% compilation time)
# 11×12 DataFrame
#  Row │ Date Time            Tick Number  Open     High     Low      Close    C ⋯
#      │ DateTime             Int64        Float64  Float64  Float64  Float64  F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2022-07-16T12:29:50        20000  13170.0    NaN      NaN    11150.0    ⋯
#    2 │ 2022-08-15T12:17:44        34509  11150.0  11900.0  10150.0  11200.0
#    3 │ 2022-09-05T09:45:14        46369  11200.0  11500.0  10410.0  10640.0
#    4 │ 2022-10-26T11:27:35        68318  10640.0  10710.0   7800.0   7800.0
#    5 │ 2022-11-28T09:46:09       124976   7800.0  11100.0   7710.0  10480.0    ⋯
#    6 │ 2022-12-06T09:13:00       133694  10480.0  10630.0  10390.0  10400.0
#    7 │ 2022-12-25T12:16:05       202103  10400.0  13170.0   9480.0  12720.0
# ...

# %%
@time fixedVolumeImbalanceBars = handleInput(
    "FixedVolumeImbalanceBars",
    Dict(
        Symbol("expectedImbalanceWindow") => 10000,
        Symbol("initialEstimateOfExpectedNTicksInBar") => 20000.0,),
    df,
    batchSize=1_000_000,  
)

fixedVolumeImbalanceBars
# Out:
# batch 1 with size 729726
#   0.301456 seconds (2.60 M allocations: 84.616 MiB, 83.61% compilation time)
# 13×12 DataFrame
#  Row │ Date Time            Tick Number  Open     High     Low      Close    C ⋯
#      │ DateTime             Int64        Float64  Float64  Float64  Float64  F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2022-07-16T12:29:50        20000  13170.0    NaN      NaN    11150.0    ⋯
#    2 │ 2022-08-13T09:08:14        31156  11150.0  11900.0  10150.0  10830.0
#    3 │ 2022-09-13T11:41:39        50600  10830.0  11500.0  10020.0  10220.0
#    4 │ 2022-10-25T11:24:15        67203  10210.0  10290.0   8330.0   8340.0
#    5 │ 2022-11-29T10:30:50       126819   8370.0  11100.0   7710.0  10500.0    ⋯
#    6 │ 2022-12-06T11:53:37       134950  10500.0  10630.0  10350.0  10350.0
#    7 │ 2023-01-01T11:16:38       239058  10360.0  14220.0   9480.0  12200.0
# ...

# %%
@time fixedTickImbalanceBars = handleInput(
    "FixedTickImbalanceBars",
    Dict(
        Symbol("expectedImbalanceWindow") => 10000,
        Symbol("initialEstimateOfExpectedNTicksInBar") => 20000.0,
    ),
    df,
    batchSize=1_000_000,  
)

fixedTickImbalanceBars
# Out:
# batch 1 with size 729726
#   0.389379 seconds (2.60 M allocations: 85.386 MiB, 22.87% gc time, 62.80% compilation time)
# 18×12 DataFrame
#  Row │ Date Time            Tick Number  Open     High     Low      Close    C ⋯
#      │ DateTime             Int64        Float64  Float64  Float64  Float64  F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2022-07-16T12:29:50        20000  13170.0    NaN      NaN    11150.0    ⋯
#    2 │ 2022-08-21T10:44:22        38008  11150.0  11900.0  10150.0  10540.0
#    3 │ 2022-09-24T10:51:00        54118  10530.0  11320.0   9310.0   9390.0
#    4 │ 2022-11-15T12:00:44       107793   9390.0  11100.0   7710.0  10400.0
#    5 │ 2022-11-29T11:04:49       127177  10400.0  10920.0  10040.0  10500.0    ⋯
#    6 │ 2022-12-07T12:04:43       138205  10500.0  10630.0  10020.0  10050.0
#    7 │ 2022-12-31T11:47:29       225076  10050.0  14220.0   9480.0  13090.0
# ...
